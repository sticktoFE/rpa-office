# %%
import openai

# 设置 OpenAI API 密钥
openai.api_key = "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"
# 将 MP3 文件转换为文本
print("开始将 mp3 文件转换为文本...")
audio_file= open("1_new.mp3", "rb")
transcript = openai.Audio.transcribe("whisper-1", audio_file)

transcription = transcript['text']
print(f"文本转换结果：{transcription}")
# Out:
# 开始将 wav 文件转换为文本...
# ...

# %%
import opencc

# 创建 OpenCC 对象，使用 s2twp.json 配置文件将简体中文转换为台湾繁体中文
# 繁体中文转换为大陆简体中文，可以使用 t2s.json 配置文件
converter = opencc.OpenCC('t2s')

# 将繁体中文字符串转换为简体中文字符串
simplified_text = converter.convert(transcription)

print(simplified_text) # 输出：你好，世界！
# Out:
# 去尝试之后 我觉得这个真的是非常可怕的一个工具 而且可能会让我们现在 很多新手的创作者感到倍感威胁 如果你还不知道 CHPT 是什么的话 你可以看一个苹果妹的教学影片 里面讲得非常清楚 可能一般人听到聊天机器人 我们很多年前一直 近年来都有这种聊天机器人 它大致上都是你问问题回答 或是大致上你跟它的对话 并不像是一个可以延续性的 可是这一次它是完全 不只有延续性还会自我学习 而且它的能力范围真的是 你实际去使用它之后 你有想要它可以做到的事情有多少 我们就来大致上示范 怎么用这个工具简单创造出 不管是你的 YouTube 频道 你的 TikTok 你的 Instagram 任何东西都可以简单 用这几分钟就创造出来 你所有需要的内容 真的超级厉害 OK 好 那我们直接开始吧 那首先我们在做一个影片的时候 你可能有大致上你想要做的方向 那以我来讲可能就是讲 可能苹果相关的东西 或是每年有新 iPhone 要出来之前 会讲一些苹果相关的爆料 那首先你看这个介面是英文的 可是你可以教它说 你现在开始要用中文回答 现在开始 好 那现在开始它就会自动进入 这个用中文回答你的这个模式 可能我们想要讲到 iPhone 15 的新闻 那觉得现在我们讲实话 其实对影片来讲 有很多 YouTuber 他们现在在做 YouTube 教学的时候 都有跟你说这个下标题 是非常一个重要的点 那有时候你可能做完这影片非常辛苦 已经想不到说要下什么标题的时候 那或许你可以反向过来 先从标题这个点来切入 那我们知道我们要做 可能 iPhone 15 相关的新闻 那我们就说 写出五则吸引人标题 我把它这边改一下 iPhone 15 爆料消息 这边非常简单喔 我这边给它的范围就是说 我要讲 iPhone 15 的爆料消息 那你给我五则吸引人的标题 其实它英文的话是满快 中文的话可能里面还要再去翻译 稍微慢一点 那其实你看它这个标题非常可怕 我没有讲到任何效能 我没有讲到任何什么东西 我没有讲到这个爆料我要爆料什么 完全没有给它任何的资讯 它里面就直接讲说 第一个当初预计发布 就让人家知道说什么时候该发布 惊人的效能提升这是第二点 第三个前所未有的拍摄体验 就让你知道说它在讲的是相机 天啊 为什么它会知道这些东西 然后再来最新爆料 配备更大的电池容量 所以你看这边这几个点 都是人家在 可能在看新手机新 
# ...

# %%
# 调用google 声音转文字api
from google.cloud import speech_v1p1beta1 as speech
# 使用Google Cloud Speech-to-Text API进行语音转文本
client = speech.SpeechClient()

with io.open(WAVE_OUTPUT_FILENAME, 'rb') as audio_file:
    content = audio_file.read()
    audio = speech.RecognitionAudio(content=content)

config = speech.RecognitionConfig(
    encoding=speech.RecognitionConfig.AudioEncoding.LINEAR16,
    sample_rate_hertz=RATE,
    language_code='en-US')

response = client.recognize(config=config, audio=audio)

# 获取识别的文本
transcription = ''
for result in response.results:
    transcription += result.alternatives[0].transcript

# 将文本转换为音频文件并保存
text_to_speech = subprocess.Popen(['espeak', '-w', 'output.wav', transcription], stdout=subprocess.PIPE, stderr=subprocess.PIPE)
text_to_speech.wait()
